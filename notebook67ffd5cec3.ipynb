# %% [markdown]
# <a href="https://www.kaggle.com/code/ibhhavvessh/notebook67ffd5cec3?scriptVersionId=264485240" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !python --version
# Out:
# Python 3.11.13
